# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      rikitea -23.1203 -134.9692     26.33        76         100
# 1        1      bubaque  11.2833  -15.8333     24.62        64          15
# 2        2     liaoyang  41.2719  123.1731      6.18        58          27
# 3        3     bilibino  68.0546  166.4372    -30.90       100         100
# 4        4  tuktoyaktuk  69.4541 -133.0374    -37.00        67           0
#
#    Wind Speed Country        Date
# 0        7.92      PF  1678030936
# 1        4.10      GW  1678030937
# 2        3.94      CN  1678030937
# 3        0.71      RU  1678030937
# 4        1.54      CA  1678030937

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City")
# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal = city_data_df.loc[(city_data_df["Max Temp"] > 23) & (city_data_df["Cloudiness"] == 0)]

# Drop any rows with null values
ideal.dropna()

# Display sample data
ideal.head()
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 52        52        carnarvon -24.8667  113.6333     25.37        70
# 55        55  arraial do cabo -22.9661  -42.0278     32.98        62
# 82        82           namibe -15.1961   12.1522     24.07        61
# 93        93          salalah  17.0151   54.0924     27.05        61
# 104      104            adrar  20.5022  -10.0711     32.04         9
#
#      Cloudiness  Wind Speed Country        Date
# 52            0       11.51      AU  1678030944
# 55            0        3.60      BR  1678030945
# 82            0        5.02      AO  1678030949
# 93            0        1.54      OM  1678030950
# 104           0        3.19      MR  1678030952

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal.drop(["City_ID","Max Temp","Cloudiness", "Wind Speed", "Date"], axis=1)

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                  City      Lat       Lng  Humidity Country Hotel Name
# 52          carnarvon -24.8667  113.6333        70      AU
# 55    arraial do cabo -22.9661  -42.0278        62      BR
# 82             namibe -15.1961   12.1522        61      AO
# 93            salalah  17.0151   54.0924        61      OM
# 104             adrar  20.5022  -10.0711         9      MR
# 118        kantabanji  20.4833   82.9167        20      IN
# 126          mormugao  15.4000   73.8000        61      IN
# 141      umm kaddadah  13.6017   26.6876        10      SD
# 159           carahue -38.7000  -73.1667        41      CL
# 192           asansol  23.6833   86.9833        22      IN
# 211              lima -12.0432  -77.0282        69      PE
# 218          rockport  28.0206  -97.0544       100      US
# 225        san rafael -34.6177  -68.3301        24      AR
# 228          pimentel  -6.8367  -79.9342        61      PE
# 238             kutum  14.2000   24.6667         8      SD
# 250             pisco -13.7000  -76.2167        73      PE
# 276         kavaratti  10.5669   72.6420        65      IN
# 309          necochea -38.5473  -58.7368        33      AR
# 322            zinder  13.8072    8.9881         7      NE
# 327            luanda  -8.8368   13.2343        62      AO
# 363     huai thalaeng  14.9970  102.6475        44      TH
# 367            shwebo  22.5667   95.7000        18      MM
# 417            sabang   5.8933   95.3214        71      ID
# 419        hervey bay -25.2986  152.8535        71      AU
# 470         abu dhabi  24.4667   54.3667        67      AE
# 543        rio cuarto -33.1307  -64.3499        33      AR
# 544  chiknayakanhalli  13.4172   76.6228        30      IN

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = f'accommodation.hotel'
params = {
    "categories":categories,
    "apiKey":geoapify_key    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lng = hotel_df.loc[index, "Lng"]
    lat = hotel_df.loc[index, "Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# carnarvon - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# namibe - nearest hotel: Hotel Chik Chik Namibe
# salalah - nearest hotel: Muscat International Hotel
# adrar - nearest hotel: No hotel found
# kantabanji - nearest hotel: Hotel Alishan Palace
# mormugao - nearest hotel: Hotel Rukhmini
# umm kaddadah - nearest hotel: No hotel found
# carahue - nearest hotel: No hotel found
# asansol - nearest hotel: No hotel found
# lima - nearest hotel: Hotel Peach Garden
# rockport - nearest hotel: Holiday Inn Express & Suites
# san rafael - nearest hotel: Hotel Regional
# pimentel - nearest hotel: Hospedaje Calle del Sol
# kutum - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# kavaratti - nearest hotel: No hotel found
# necochea - nearest hotel: Cabañas Río Quequén
# zinder - nearest hotel: Hotel Zentral
# luanda - nearest hotel: Hotel Forum
# huai thalaeng - nearest hotel: No hotel found
# shwebo - nearest hotel: Pyi Shwe Theingha
# sabang - nearest hotel: Sabang Hill
# hervey bay - nearest hotel: Hervey Bay Hotel
# abu dhabi - nearest hotel: Marriott Downtown Abu-Dhabi
# rio cuarto - nearest hotel: Marluc
# chiknayakanhalli - nearest hotel: No hotel found
#                  City      Lat       Lng  Humidity Country  \
# 52          carnarvon -24.8667  113.6333        70      AU
# 55    arraial do cabo -22.9661  -42.0278        62      BR
# 82             namibe -15.1961   12.1522        61      AO
# 93            salalah  17.0151   54.0924        61      OM
# 104             adrar  20.5022  -10.0711         9      MR
# 118        kantabanji  20.4833   82.9167        20      IN
# 126          mormugao  15.4000   73.8000        61      IN
# 141      umm kaddadah  13.6017   26.6876        10      SD
# 159           carahue -38.7000  -73.1667        41      CL
# 192           asansol  23.6833   86.9833        22      IN
# 211              lima -12.0432  -77.0282        69      PE
# 218          rockport  28.0206  -97.0544       100      US
# 225        san rafael -34.6177  -68.3301        24      AR
# 228          pimentel  -6.8367  -79.9342        61      PE
# 238             kutum  14.2000   24.6667         8      SD
# 250             pisco -13.7000  -76.2167        73      PE
# 276         kavaratti  10.5669   72.6420        65      IN
# 309          necochea -38.5473  -58.7368        33      AR
# 322            zinder  13.8072    8.9881         7      NE
# 327            luanda  -8.8368   13.2343        62      AO
# 363     huai thalaeng  14.9970  102.6475        44      TH
# 367            shwebo  22.5667   95.7000        18      MM
# 417            sabang   5.8933   95.3214        71      ID
# 419        hervey bay -25.2986  152.8535        71      AU
# 470         abu dhabi  24.4667   54.3667        67      AE
# 543        rio cuarto -33.1307  -64.3499        33      AR
# 544  chiknayakanhalli  13.4172   76.6228        30      IN
#
#                        Hotel Name
# 52                 No hotel found
# 55                 No hotel found
# 82         Hotel Chik Chik Namibe
# 93     Muscat International Hotel
# 104                No hotel found
# 118          Hotel Alishan Palace
# 126                Hotel Rukhmini
# 141                No hotel found
# 159                No hotel found
# 192                No hotel found
# 211            Hotel Peach Garden
# 218  Holiday Inn Express & Suites
# 225                Hotel Regional
# 228       Hospedaje Calle del Sol
# 238                No hotel found
# 250                    La Portada
# 276                No hotel found
# 309           Cabañas Río Quequén
# 322                 Hotel Zentral
# 327                   Hotel Forum
# 363                No hotel found
# 367             Pyi Shwe Theingha
# 417                   Sabang Hill
# 419              Hervey Bay Hotel
# 470   Marriott Downtown Abu-Dhabi
# 543                        Marluc
# 544                No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot

map_plot2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City",
    hover_cols = ["Hotel Name","Country"])

# Display the map
map_plot2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
